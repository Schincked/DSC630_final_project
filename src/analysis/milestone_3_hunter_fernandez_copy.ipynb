# %%
import pandas as pd
import plotly.graph_objects as go

# Load the dataset
data = pd.read_csv('NVDA.csv', parse_dates=['Date'])

# Sort data by date
data = data.sort_values('Date')

# Create a candlestick chart
fig = go.Figure(data=[go.Candlestick(x=data['Date'],
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close'])])

fig.update_layout(title="NVIDIA Stock Price Candlestick Chart",
                  xaxis_title="Date",
                  yaxis_title="Price (USD)")

fig.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a figure and axis
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot the stock closing price (Line)
ax1.set_xlabel('Date')
ax1.set_ylabel('Close Price (USD)', color='tab:blue')
ax1.plot(data['Date'], data['Close'], color='tab:blue', label="Close Price")
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Create a second y-axis to plot Volume (Bar)
ax2 = ax1.twinx()
ax2.set_ylabel('Volume', color='tab:red')
ax2.bar(data['Date'], data['Volume'], color='tab:red', alpha=0.3, label="Volume")
ax2.tick_params(axis='y', labelcolor='tab:red')

fig.tight_layout()
plt.title("NVIDIA Stock Price vs Trading Volume")
plt.show()

# %%
# Line plot for stock price over time
plt.figure(figsize=(12, 6))
sns.lineplot(x='Date', y='Close', data=data, label='Close Price')
plt.title('NVIDIA Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Close Price (USD)')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\hunte\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\hunte\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming the data is already loaded
# Calculate volatility (High - Low)
data['Volatility'] = data['High'] - data['Low']

# Set the figure size
plt.figure(figsize=(12, 6))

# Plot volatility over time
sns.lineplot(x='Date', y='Volatility', data=data, color='orange')

# Title and labels
plt.title('NVIDIA Stock Price Volatility Over Time')
plt.xlabel('Date')
plt.ylabel('Price Volatility (USD)')

# Rotate x-ticks for readability
plt.xticks(rotation=45)

# Use tight layout with padding to prevent cutting off labels
plt.tight_layout(pad=3.0)

# Show plot
plt.show()
# Out:
# C:\Users\hunte\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\hunte\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.

# %%
# Example product release dates for RTX and GTX 
rtx_release2 = pd.to_datetime('2018-09-20')  # RTX 20 series
rtx_release3 = pd.to_datetime('2020-09-17')  # RTX 30 series
rtx_release4 = pd.to_datetime('2022-10-12')  # RTX 40 series
gtx_release = pd.to_datetime('2005-06-22')  #GTX 7800
dlss_release2 = pd.to_datetime('2020-04-01')  #DLSS 2.0
dlss_release3 = pd.to_datetime('2022-9-01')  #DLSS 3.0
dlss_release35 = pd.to_datetime('2023-09-01')  #DLSS 3.5

# Plot closing price with event markers
plt.figure(figsize=(12, 6))
sns.lineplot(x='Date', y='Close', data=data, label='Close Price')
plt.axvline(x=rtx_release2, color='green', linestyle='--', label='RTX 2000 series Release')
plt.axvline(x=rtx_release3, color='purple', linestyle='--', label='RTX 3000 series Release')
plt.axvline(x=rtx_release4, color='orange', linestyle='--', label='RTX 4000 series Release')
plt.axvline(x=gtx_release, color='red', linestyle='--', label='GTX 7800 Release')
plt.axvline(x=dlss_release2, color='yellow', linestyle='--', label='dlss 2.0 Release')
plt.axvline(x=dlss_release3, color='blue', linestyle='--', label='dlss 3.0 release')
plt.axvline(x=dlss_release35, color='pink', linestyle='--', label='dlss 3.5 Release')

plt.title('NVIDIA Stock Price with Product Release Markers')
plt.xlabel('Date')
plt.ylabel('Close Price (USD)')
plt.legend()
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\hunte\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\hunte\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
